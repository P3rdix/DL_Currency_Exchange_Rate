# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.metrics import (
    mean_absolute_error,
    mean_absolute_percentage_error,
    mean_squared_error,
)
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
# Out:
# 2023-10-12 13:31:09.420961: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "

# %%
data = pd.read_csv("../data.csv")
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Australia  Europe  Brazil  Canada   China  \
# 0             0  2010-01-04     0.9133  1.4419  1.7200  1.0377  6.8273
# 1             1  2010-01-05     0.9143  1.4402  1.7296  1.0371  6.8258
# 2             2  2010-01-06     0.9189  1.4404  1.7292  1.0333  6.8272
# 3             3  2010-01-07     0.9168  1.4314  1.7409  1.0351  6.8280
# 4             4  2010-01-08     0.9218  1.4357  1.7342  1.0345  6.8274
#
#    Denmark  Hong Kong  India  Japan  Malaysia
# 0   5.1597     7.7555  46.27  92.55     3.396
# 1   5.1668     7.7564  46.13  91.48     3.385
# 2   5.1638     7.7546  45.72  92.53     3.379
# 3   5.1981     7.7539  45.67  93.31     3.368
# 4   5.1827     7.7553  45.50  92.70     3.375

# %%
data.drop("Unnamed: 0.1", axis=1, inplace=True)
data.rename(columns={"Unnamed: 0": "Date"}, inplace=True)
data["Date"] = pd.to_datetime(data["Date"])
data.set_index("Date", inplace=True)
data.replace(0, np.nan, inplace=True)

# %%
data
# Out:
#             Australia  Europe  Brazil  Canada   China  Denmark  Hong Kong  \
# Date
# 2010-01-04     0.9133  1.4419  1.7200  1.0377  6.8273   5.1597     7.7555
# 2010-01-05     0.9143  1.4402  1.7296  1.0371  6.8258   5.1668     7.7564
# 2010-01-06     0.9189  1.4404  1.7292  1.0333  6.8272   5.1638     7.7546
# 2010-01-07     0.9168  1.4314  1.7409  1.0351  6.8280   5.1981     7.7539
# 2010-01-08     0.9218  1.4357  1.7342  1.0345  6.8274   5.1827     7.7553
# ...               ...     ...     ...     ...     ...      ...        ...
# 2019-12-27     0.6978  1.1174  4.0507  1.3073  6.9954   6.6829     7.7874
# 2019-12-28        NaN     NaN     NaN     NaN     NaN      NaN        NaN
# 2019-12-29        NaN     NaN     NaN     NaN     NaN      NaN        NaN
# 2019-12-30     0.7004  1.1217  4.0152  1.3058  6.9864   6.6589     7.7857
# 2019-12-31     0.7030  1.1227  4.0190  1.2962  6.9618   6.6554     7.7894
#
#             India   Japan  Malaysia
# Date
# 2010-01-04  46.27   92.55    3.3960
# 2010-01-05  46.13   91.48    3.3850
# 2010-01-06  45.72   92.53    3.3790
# 2010-01-07  45.67   93.31    3.3680
# 2010-01-08  45.50   92.70    3.3750
# ...           ...     ...       ...
# 2019-12-27  71.45  109.47    4.1260
# 2019-12-28    NaN     NaN       NaN
# 2019-12-29    NaN     NaN       NaN
# 2019-12-30  71.30  108.85    4.1053
# 2019-12-31  71.36  108.67    4.0918
#
# [3648 rows x 10 columns]

# %%
data.interpolate(method="linear", limit_direction="forward")
# Out:
#             Australia    Europe    Brazil  Canada   China  Denmark  Hong Kong  \
# Date
# 2010-01-04   0.913300  1.441900  1.720000  1.0377  6.8273   5.1597   7.755500
# 2010-01-05   0.914300  1.440200  1.729600  1.0371  6.8258   5.1668   7.756400
# 2010-01-06   0.918900  1.440400  1.729200  1.0333  6.8272   5.1638   7.754600
# 2010-01-07   0.916800  1.431400  1.740900  1.0351  6.8280   5.1981   7.753900
# 2010-01-08   0.921800  1.435700  1.734200  1.0345  6.8274   5.1827   7.755300
# ...               ...       ...       ...     ...     ...      ...        ...
# 2019-12-27   0.697800  1.117400  4.050700  1.3073  6.9954   6.6829   7.787400
# 2019-12-28   0.698667  1.118833  4.038867  1.3068  6.9924   6.6749   7.786833
# 2019-12-29   0.699533  1.120267  4.027033  1.3063  6.9894   6.6669   7.786267
# 2019-12-30   0.700400  1.121700  4.015200  1.3058  6.9864   6.6589   7.785700
# 2019-12-31   0.703000  1.122700  4.019000  1.2962  6.9618   6.6554   7.789400
#
#             India       Japan  Malaysia
# Date
# 2010-01-04  46.27   92.550000    3.3960
# 2010-01-05  46.13   91.480000    3.3850
# 2010-01-06  45.72   92.530000    3.3790
# 2010-01-07  45.67   93.310000    3.3680
# 2010-01-08  45.50   92.700000    3.3750
# ...           ...         ...       ...
# 2019-12-27  71.45  109.470000    4.1260
# 2019-12-28  71.40  109.263333    4.1191
# 2019-12-29  71.35  109.056667    4.1122
# 2019-12-30  71.30  108.850000    4.1053
# 2019-12-31  71.36  108.670000    4.0918
#
# [3648 rows x 10 columns]

# %%
data.interpolate(method="linear", limit_direction="forward", inplace=True)
LOOK_BACK = 30
PREDICT_DAY = 1
SPLIT_RATIO = 0.8

# %%
def Create_Data(
    data, lookback=LOOK_BACK, pred_len=PREDICT_DAY, split_ratio=SPLIT_RATIO
):
    if lookback < 2:
        print("ERROR: Lookback too small")
        return -1

    # declarations

    x = {}
    y = {}
    xtr = {}
    xt = {}
    ytr = {}
    yt = {}
    scalers = {}

    # Creating stepped data

    for i in data.columns:
        xtemp = pd.DataFrame(data[i])
        for j in range(1, lookback + 1):
            xtemp[i + str(j)] = data[i].shift(-1 * j)
        x[i] = xtemp.dropna()

    # Splitting data into x and y

    for i in x.keys():
        y[i] = pd.DataFrame(x[i].iloc[:, -pred_len])
        x[i] = x[i].iloc[:, :-pred_len]

    # Normalizing x and y values

    for i in x.keys():
        scalers[i + "_x"] = MinMaxScaler(feature_range=(0, 1))
        x[i] = scalers[i + "_x"].fit_transform(x[i])
        scalers[i + "_y"] = MinMaxScaler(feature_range=(0, 1))
        y[i] = scalers[i + "_y"].fit_transform(y[i])

    # setting train and test sizes

    tr_len = int(split_ratio * y["India"].shape[0])
    t_len = y["India"].shape[0] - tr_len

    # creating training and testing data

    for i in x.keys():
        xtr[i] = x[i][:tr_len]
        ytr[i] = y[i][:tr_len]
        xt[i] = x[i][-t_len:]
        yt[i] = y[i][-t_len:]

    # returning pertinent data

    return x, y, xtr, xt, ytr, yt, scalers

# %%
x, y, xtr, xt, ytr, yt, scalers = Create_Data(data)

# %%
def Create_model(x, y, lookback=LOOK_BACK, Pred_size=PREDICT_DAY):
    models = {}
    for i in x.keys():
        models[i] = Sequential()
        models[i].add(Dense(32, input_shape=(LOOK_BACK,), activation="relu"))
        models[i].add(Dense(64, activation="relu"))
        models[i].add(Dropout(0.2))
        models[i].add(Dense(128, activation="relu"))
        models[i].add(Dropout(0.2))
        models[i].add(Dense(64, activation="relu"))
        models[i].add(Dropout(0.2))
        models[i].add(Dense(16, activation="relu"))
        models[i].add(Dense(Pred_size))
        models[i].compile(loss="mean_squared_error", optimizer="adam")
        print(i)
    return models

# %%
m = Create_model(x, y)
# Out:
# 2023-10-12 13:31:11.213319: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-12 13:31:11.238628: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-12 13:31:11.239063: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-12 13:31:11.242395: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-12 13:31:11.242830: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-12 13:31:11.243140: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-12 13:31:11.363150: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-12 13:31:11.363529: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-12 13:31:11.363904: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-12 13:31:11.364134: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 730 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2023-10-12 13:31:11.364556: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Australia
# Europe
# Brazil
# Canada
# China
# Denmark
# Hong Kong
# India
# Japan
# Malaysia

# %%
def Execute_model(model, xtr, ytr, xt, yt, scaler):
    MAPE = {}
    MAE = {}
    MSE = {}
    for i in model.keys():
        print(i)
        # Creating EarlyStopping and ReduceLROnPlateau callbacks
        es = EarlyStopping(monitor="val_loss", mode="min", verbose=1, patience=10)
        reduce_lr = ReduceLROnPlateau(
            monitor="val_loss", factor=0.2, patience=5, min_lr=0.0001
        )

        # Training the model with EarlyStopping and ReduceLROnPlateau callbacks
        model[i].fit(
            xtr[i],
            ytr[i],
            epochs=100,
            batch_size=64,
            verbose=1,
            validation_split=0.2,
            callbacks=[es, reduce_lr],
        )

        # collecting predicted and actual values
        temp = model[i].predict(xt[i])
        pred = scaler[i + "_y"].inverse_transform(temp)
        act = scaler[i + "_y"].inverse_transform(yt[i])

        # calculating Mean Square Error, Mean Absolute Error, and Mean Absolute Error
        MSE[i] = mean_squared_error(act, pred)
        MAE[i] = mean_absolute_error(act, pred)
        MAPE[i] = mean_absolute_percentage_error(act, pred)

    # Tabulating Data
    results = pd.DataFrame([MSE, MAE, MAPE])
    results["Metric"] = ["MSE", "MAE", "MAPE"]
    results.set_index("Metric", inplace=True)

    return results

# %%
result = Execute_model(m, xtr, ytr, xt, yt, scalers)
# Out:
# Australia
# Epoch 1/100
# 2023-10-12 13:31:13.079470: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55a438f15200 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-12 13:31:13.079535: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1660 Ti, Compute Capability 7.5
# 2023-10-12 13:31:13.091638: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-12 13:31:13.123373: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8902
# 2023-10-12 13:31:13.245058: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 37/37 [==============================] - 3s 12ms/step - loss: 0.0397 - val_loss: 8.2262e-04 - lr: 0.0010
# Epoch 2/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0142 - val_loss: 0.0013 - lr: 0.0010
# Epoch 3/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0102 - val_loss: 0.0017 - lr: 0.0010
# Epoch 4/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0078 - val_loss: 0.0015 - lr: 0.0010
# Epoch 5/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0067 - val_loss: 0.0024 - lr: 0.0010
# Epoch 6/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0060 - val_loss: 0.0013 - lr: 0.0010
# Epoch 7/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0010 - lr: 2.0000e-04
# Epoch 8/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0012 - lr: 2.0000e-04
# Epoch 9/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0013 - lr: 2.0000e-04
# Epoch 10/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 9.9362e-04 - lr: 2.0000e-04
# Epoch 11/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0051 - val_loss: 0.0010 - lr: 2.0000e-04
# Epoch 11: early stopping
# 23/23 [==============================] - 0s 2ms/step
# Europe
# Epoch 1/100
# 37/37 [==============================] - 2s 8ms/step - loss: 0.0521 - val_loss: 0.0019 - lr: 0.0010
# Epoch 2/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0152 - val_loss: 0.0017 - lr: 0.0010
# Epoch 3/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0109 - val_loss: 0.0017 - lr: 0.0010
# Epoch 4/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0084 - val_loss: 0.0021 - lr: 0.0010
# Epoch 5/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0077 - val_loss: 0.0025 - lr: 0.0010
# Epoch 6/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0070 - val_loss: 0.0016 - lr: 0.0010
# Epoch 7/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0021 - lr: 0.0010
# Epoch 8/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0054 - val_loss: 0.0019 - lr: 2.0000e-04
# Epoch 9/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0018 - lr: 2.0000e-04
# Epoch 10/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0019 - lr: 2.0000e-04
# Epoch 11/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0047 - val_loss: 0.0020 - lr: 2.0000e-04
# Epoch 12/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0051 - val_loss: 0.0019 - lr: 2.0000e-04
# Epoch 13/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0018 - lr: 1.0000e-04
# Epoch 14/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0047 - val_loss: 0.0021 - lr: 1.0000e-04
# Epoch 15/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0018 - lr: 1.0000e-04
# Epoch 16/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0046 - val_loss: 0.0019 - lr: 1.0000e-04
# Epoch 16: early stopping
# 23/23 [==============================] - 0s 2ms/step
# Brazil
# Epoch 1/100
# 37/37 [==============================] - 2s 11ms/step - loss: 0.0434 - val_loss: 0.0115 - lr: 0.0010
# Epoch 2/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0063 - val_loss: 0.0091 - lr: 0.0010
# Epoch 3/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0060 - lr: 0.0010
# Epoch 4/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0071 - lr: 0.0010
# Epoch 5/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0078 - lr: 0.0010
# Epoch 6/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0178 - lr: 0.0010
# Epoch 7/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0181 - lr: 0.0010
# Epoch 8/100
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0025 - val_loss: 0.0105 - lr: 0.0010
# Epoch 9/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0119 - lr: 2.0000e-04
# Epoch 10/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0110 - lr: 2.0000e-04
# Epoch 11/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0115 - lr: 2.0000e-04
# Epoch 12/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0126 - lr: 2.0000e-04
# Epoch 13/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0130 - lr: 2.0000e-04
# Epoch 13: early stopping
# 23/23 [==============================] - 0s 2ms/step
# Canada
# Epoch 1/100
# 37/37 [==============================] - 2s 10ms/step - loss: 0.0270 - val_loss: 0.0158 - lr: 0.0010
# Epoch 2/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0052 - val_loss: 0.0147 - lr: 0.0010
# Epoch 3/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0180 - lr: 0.0010
# Epoch 4/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0220 - lr: 0.0010
# Epoch 5/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0261 - lr: 0.0010
# Epoch 6/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0452 - lr: 0.0010
# Epoch 7/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0304 - lr: 0.0010
# Epoch 8/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0256 - lr: 2.0000e-04
# Epoch 9/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0272 - lr: 2.0000e-04
# Epoch 10/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 0.0309 - lr: 2.0000e-04
# Epoch 11/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0328 - lr: 2.0000e-04
# Epoch 12/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0275 - lr: 2.0000e-04
# Epoch 12: early stopping
# 23/23 [==============================] - 0s 2ms/step
# China
# Epoch 1/100
# 37/37 [==============================] - 2s 10ms/step - loss: 0.0081 - val_loss: 0.0329 - lr: 0.0010
# Epoch 2/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0270 - lr: 0.0010
# Epoch 3/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0365 - lr: 0.0010
# Epoch 4/100
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0020 - val_loss: 0.0389 - lr: 0.0010
# Epoch 5/100
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 0.0280 - lr: 0.0010
# Epoch 6/100
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0241 - lr: 0.0010
# Epoch 7/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0244 - lr: 0.0010
# Epoch 8/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0305 - lr: 0.0010
# Epoch 9/100
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0013 - val_loss: 0.0492 - lr: 0.0010
# Epoch 10/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0338 - lr: 0.0010
# Epoch 11/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0365 - lr: 0.0010
# Epoch 12/100
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0357 - lr: 2.0000e-04
# Epoch 13/100
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0358 - lr: 2.0000e-04
# Epoch 14/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0348 - lr: 2.0000e-04
# Epoch 15/100
# 37/37 [==============================] - 0s 8ms/step - loss: 9.4511e-04 - val_loss: 0.0447 - lr: 2.0000e-04
# Epoch 16/100
# 37/37 [==============================] - 0s 7ms/step - loss: 9.7659e-04 - val_loss: 0.0453 - lr: 2.0000e-04
# Epoch 16: early stopping
# 23/23 [==============================] - 0s 2ms/step
# Denmark
# Epoch 1/100
# 37/37 [==============================] - 2s 10ms/step - loss: 0.0371 - val_loss: 0.0092 - lr: 0.0010
# Epoch 2/100
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0095 - val_loss: 0.0176 - lr: 0.0010
# Epoch 3/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0066 - val_loss: 0.0126 - lr: 0.0010
# Epoch 4/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0225 - lr: 0.0010
# Epoch 5/100
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0045 - val_loss: 0.0456 - lr: 0.0010
# Epoch 6/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0039 - val_loss: 0.0337 - lr: 0.0010
# Epoch 7/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 0.0409 - lr: 2.0000e-04
# Epoch 8/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0033 - val_loss: 0.0487 - lr: 2.0000e-04
# Epoch 9/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0035 - val_loss: 0.0390 - lr: 2.0000e-04
# Epoch 10/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0389 - lr: 2.0000e-04
# Epoch 11/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0438 - lr: 2.0000e-04
# Epoch 11: early stopping
# 23/23 [==============================] - 0s 2ms/step
# Hong Kong
# Epoch 1/100
# 37/37 [==============================] - 2s 9ms/step - loss: 0.0061 - val_loss: 0.0091 - lr: 0.0010
# Epoch 2/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0052 - lr: 0.0010
# Epoch 3/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0144 - lr: 0.0010
# Epoch 4/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0099 - lr: 0.0010
# Epoch 5/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0042 - lr: 0.0010
# Epoch 6/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0088 - lr: 0.0010
# Epoch 7/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0060 - lr: 0.0010
# Epoch 8/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0129 - lr: 0.0010
# Epoch 9/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 0.0087 - lr: 0.0010
# Epoch 10/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0059 - lr: 0.0010
# Epoch 11/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0102 - lr: 2.0000e-04
# Epoch 12/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0074 - lr: 2.0000e-04
# Epoch 13/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 0.0074 - lr: 2.0000e-04
# Epoch 14/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0010 - val_loss: 0.0074 - lr: 2.0000e-04
# Epoch 15/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 0.0078 - lr: 2.0000e-04
# Epoch 15: early stopping
# 23/23 [==============================] - 0s 2ms/step
# India
# Epoch 1/100
# 37/37 [==============================] - 2s 8ms/step - loss: 0.0228 - val_loss: 0.0278 - lr: 0.0010
# Epoch 2/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0287 - lr: 0.0010
# Epoch 3/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0333 - lr: 0.0010
# Epoch 4/100
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0043 - val_loss: 0.0276 - lr: 0.0010
# Epoch 5/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0331 - lr: 0.0010
# Epoch 6/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0217 - lr: 0.0010
# Epoch 7/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0312 - lr: 0.0010
# Epoch 8/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0181 - lr: 0.0010
# Epoch 9/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0284 - lr: 0.0010
# Epoch 10/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0237 - lr: 0.0010
# Epoch 11/100
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0019 - val_loss: 0.0229 - lr: 0.0010
# Epoch 12/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0186 - lr: 0.0010
# Epoch 13/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0303 - lr: 0.0010
# Epoch 14/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0283 - lr: 2.0000e-04
# Epoch 15/100
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0016 - val_loss: 0.0258 - lr: 2.0000e-04
# Epoch 16/100
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0016 - val_loss: 0.0281 - lr: 2.0000e-04
# Epoch 17/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0240 - lr: 2.0000e-04
# Epoch 18/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0294 - lr: 2.0000e-04
# Epoch 18: early stopping
# 23/23 [==============================] - 0s 2ms/step
# Japan
# Epoch 1/100
# 37/37 [==============================] - 2s 10ms/step - loss: 0.0673 - val_loss: 0.0021 - lr: 0.0010
# Epoch 2/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0154 - val_loss: 0.0064 - lr: 0.0010
# Epoch 3/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0098 - val_loss: 0.0130 - lr: 0.0010
# Epoch 4/100
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0069 - val_loss: 0.0079 - lr: 0.0010
# Epoch 5/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0059 - val_loss: 0.0211 - lr: 0.0010
# Epoch 6/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0054 - val_loss: 0.0094 - lr: 0.0010
# Epoch 7/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0046 - val_loss: 0.0133 - lr: 2.0000e-04
# Epoch 8/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0043 - val_loss: 0.0118 - lr: 2.0000e-04
# Epoch 9/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0041 - val_loss: 0.0164 - lr: 2.0000e-04
# Epoch 10/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 0.0183 - lr: 2.0000e-04
# Epoch 11/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 0.0126 - lr: 2.0000e-04
# Epoch 11: early stopping
# 23/23 [==============================] - 0s 2ms/step
# Malaysia
# Epoch 1/100
# 37/37 [==============================] - 2s 13ms/step - loss: 0.0401 - val_loss: 0.0255 - lr: 0.0010
# Epoch 2/100
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0056 - val_loss: 0.0244 - lr: 0.0010
# Epoch 3/100
# 37/37 [==============================] - 0s 8ms/step - loss: 0.0039 - val_loss: 0.0369 - lr: 0.0010
# Epoch 4/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0450 - lr: 0.0010
# Epoch 5/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0033 - val_loss: 0.0300 - lr: 0.0010
# Epoch 6/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0288 - lr: 0.0010
# Epoch 7/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0333 - lr: 0.0010
# Epoch 8/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0383 - lr: 2.0000e-04
# Epoch 9/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0452 - lr: 2.0000e-04
# Epoch 10/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0453 - lr: 2.0000e-04
# Epoch 11/100
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0416 - lr: 2.0000e-04
# Epoch 12/100
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0388 - lr: 2.0000e-04
# Epoch 12: early stopping
# 23/23 [==============================] - 0s 2ms/step

# %%
result
# Out:
#         Australia    Europe    Brazil    Canada     China   Denmark  \
# Metric
# MSE      0.000272  0.000342  0.205877  0.007709  0.070281  0.162679
# MAE      0.013246  0.015366  0.446495  0.087230  0.243625  0.396067
# MAPE     0.018647  0.013109  0.116713  0.066370  0.035476  0.060631
#
#         Hong Kong      India      Japan  Malaysia
# Metric
# MSE      0.000439  41.866772  28.209335  0.068689
# MAE      0.020491   6.409885   5.269444  0.260594
# MAPE     0.002614   0.091958   0.047978  0.063625

# %%
import json
import os

# Define the filename
filename = "../results.json"

# Check if the file exists
if os.path.isfile(filename):
    # If the file exists, load the existing data
    with open(filename, "r") as f:
        data = json.load(f)
else:
    # If the file doesn't exist, create an empty dictionary
    data = {}

# Add the result to the dictionary
data["FNN"] = result.to_dict()

# Write the dictionary to the file
with open(filename, "w") as f:
    json.dump(data, f)
